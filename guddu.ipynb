# %%
import pandas as pd
import openpyxl as xl

# %%
job=pd.read_csv("GFDLNFO_BACKADJUSTED_01012021.csv")
job
# Out:
#                        Ticker        Date      Time    Open    High     Low  \
# 0       AARTIIND28JAN211160PE  01/01/2021  09:47:59   20.00   20.00   20.00
# 1       AARTIIND28JAN211160PE  01/01/2021  10:02:59   20.30   20.30   20.30
# 2       AARTIIND28JAN211200PE  01/01/2021  09:41:59   30.00   30.00   30.00
# 3       AARTIIND28JAN211200PE  01/01/2021  09:45:59   30.00   30.00   30.00
# 4       AARTIIND28JAN211200PE  01/01/2021  09:58:59   30.00   34.05   30.00
# ...                       ...         ...       ...     ...     ...     ...
# 377938                ZEEL-II  01/01/2021  12:23:59  226.65  226.65  226.65
# 377939                ZEEL-II  01/01/2021  13:17:59  226.65  227.40  226.65
# 377940                ZEEL-II  01/01/2021  13:36:59  227.40  227.40  226.40
# 377941                ZEEL-II  01/01/2021  14:10:59  226.40  227.00  226.40
# 377942                ZEEL-II  01/01/2021  15:25:59  227.00  227.10  227.00
#
#          Close  Volume  Open Interest
# ...

# %%
job2=job.loc[(job['Close']>200)&(job['Ticker'].str.startswith('BANKNIFTY'))&(job['Time'].str.startswith('10:00'))]
job2
# Out:
#                         Ticker        Date      Time      Open      High  \
# 45312  BANKNIFTY07JAN2130400CE  01/01/2021  10:00:59   1056.00   1056.00
# 45768  BANKNIFTY07JAN2130500CE  01/01/2021  10:00:59    971.85    971.85
# 47485  BANKNIFTY07JAN2130800CE  01/01/2021  10:00:59    734.20    735.05
# 48144  BANKNIFTY07JAN2130900CE  01/01/2021  10:00:59    665.00    665.00
# 48447  BANKNIFTY07JAN2130900PE  01/01/2021  10:00:59    198.75    207.15
# ...                        ...         ...       ...       ...       ...
# 80674  BANKNIFTY28JAN2132500CE  01/01/2021  10:00:59    454.55    454.55
# 81212  BANKNIFTY28JAN2133000CE  01/01/2021  10:00:59    315.05    315.70
# 81656  BANKNIFTY28JAN2133500CE  01/01/2021  10:00:59    216.05    216.05
# 82659              BANKNIFTY-I  01/01/2021  10:00:59  31386.00  31389.45
# 83032             BANKNIFTY-II  01/01/2021  10:00:59  31435.80  31435.80
#
#             Low     Close  Volume  Open Interest
# ...

# %%
job2.style.hide_index()
# Out:
# C:\Users\thegu\AppData\Local\Temp\ipykernel_12964\1051018954.py:1: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   job2.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_4d927">
#   <thead>
#     <tr>
#       <th id="T_4d927_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_4d927_level0_col1" class="col_heading level0 col1" >Date</th>
#       <th id="T_4d927_level0_col2" class="col_heading level0 col2" >Time</th>
#       <th id="T_4d927_level0_col3" class="col_heading level0 col3" >Open</th>
#       <th id="T_4d927_level0_col4" class="col_heading level0 col4" >High</th>
#       <th id="T_4d927_level0_col5" class="col_heading level0 col5" >Low</th>
#       <th id="T_4d927_level0_col6" class="col_heading level0 col6" >Close</th>
#       <th id="T_4d927_level0_col7" class="col_heading level0 col7" >Volume</th>
#       <th id="T_4d927_level0_col8" class="col_heading level0 col8" >Open Interest</th>
# ...

# %%
job2.to_excel("jugglers47.xlsx")
